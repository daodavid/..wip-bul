# %%
from daomath.fields import VectorField

# %%
field = VectorField(lambda x,y : x ,lambda x,y: y)

field.plot_field(append=True)
field2 = VectorField(lambda x,y : x+y ,lambda x,y: y-x)

field2.plot_field()
